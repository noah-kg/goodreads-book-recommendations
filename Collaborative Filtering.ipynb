# %% [markdown]
# # Import Libraries & Tools

# %%
import pandas as pd
import numpy as np

from scipy.sparse import coo_matrix
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Import Data

# %%
my_books = pd.read_csv('liked_books.csv')

#ensure `book_id` is a string
my_books['book_id'] = my_books['book_id'].astype(str)
my_books.head()
# Out:
#    user_id   book_id  rating                   title
# 0       -1    434903       5     The Rings of Saturn
# 1       -1  11047557       5   The Lord of the Rings
# 2       -1  29983711       5                Pachinko
# 3       -1  12073240       5  The Remains of the Day
# 4       -1     11297       5          Norwegian Wood

# %% [markdown]
# # Find Similar Users

# %%
#get the correct book_id values
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

#ensure no duplicates in our book list
book_set = set(my_books['book_id'])

# %%
#get # of times a user read a book on our list
overlap_users = {}

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        book_id = csv_book_mapping.get(csv_id)
        
        if book_id in book_set:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1

# %%
#filter users who have read 25% or more of the books in my_books
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/4])

print(f'# of users who have read at least 1 book on our list: {len(overlap_users)}')
print(f'# of users who have read at least 25% of books on our list: {len(filtered_overlap_users)}')

# %% [markdown]
# # Find Similar Users Ratings

# %%
#get users book list
interactions_list = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, book_id, rating])

# %% [markdown]
# # Create Collaborative Filtering Matrix

# %%
#create df with similar users book lists and add our book list to it
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])
interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions])
interactions
# Out:
#         user_id   book_id rating
# 0            -1    434903      5
# 1            -1  11047557      5
# 2            -1  29983711      5
# 3            -1  12073240      5
# 4            -1     11297      5
# ...         ...       ...    ...
# 1139179  437856  30091914      5
# 1139180  437856  23281518      4
# 1139181  437856  27430351      5
# 1139182  437856  33295190      0
# 1139183  437856  28052185      5
#
# [1139209 rows x 3 columns]

# %%
#ensure columns are correct dtypes
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

#gives sequential index for user and book id
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))
ratings_mat_coo.shape
# Out:
# (93, 421622)

# %%
ratings_mat = ratings_mat_coo.tocsr()
interactions[interactions["user_id"] == "-1"].head()
# Out:
#   user_id   book_id  rating  user_index  book_index
# 0      -1    434903       5           0      323091
# 1      -1  11047557       5           0       14591
# 2      -1  29983711       5           0      269638
# 3      -1  12073240       5           0       28964
# 4      -1     11297       5           0       18294

# %%
#get our index based on above
my_index = 0

# %%
#get similarities to other users (closer to 1 = more similar)
similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()
similarity[0]
# Out:
# 1.0000000000000007

# %%
#finds X indices of most similar users to us in terms of book tastes
find_similar_users = 30
indices = np.argpartition(similarity, -find_similar_users)[-find_similar_users:]
indices
# Out:
# array([28, 82, 53, 19, 67, 21, 43, 70, 42, 85, 73, 87, 75, 35, 27, 78, 52,
#        58, 80, 79, 72, 51, 41, 39, 38,  2, 22, 33, 29,  0], dtype=int64)

# %%
#gets user id based on above indices
similar_users = interactions[interactions["user_index"].isin(indices)].copy()
similar_users = similar_users[similar_users["user_id"] != "-1"]
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 16277      7869      5107       5          87      333837
# 16278      7869      2657       5          87      239600
# 16279      7869      4671       5          87      327692
# 16280      7869     10975       5          87       13525
# 16281      7869     12220       5          87       30878
# ...         ...       ...     ...         ...         ...
# 1139179  437856  30091914       5          79      270741
# 1139180  437856  23281518       4          79      193283
# 1139181  437856  27430351       5          79      247153
# 1139182  437856  33295190       0          79      293965
# 1139183  437856  28052185       5          79      251024
#
# [51474 rows x 5 columns]

# %%
#how many time each book appeared in above recommendations
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean'])
book_recs
# Out:
#           count      mean
# book_id
# 1             6  4.166667
# 10000         5  1.000000
# 100006        1  0.000000
# 10000613      2  0.000000
# 10001693      1  0.000000
# ...         ...       ...
# 9997          1  0.000000
# 9998          7  0.714286
# 999816        1  0.000000
# 999898        1  0.000000
# 9999          5  0.000000
#
# [35054 rows x 2 columns]

# %%
#gets book title so that the above makes more sense
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

#merge two datasets to get the titles into our recommendations
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")
book_recs
# Out:
#         book_id  count      mean  \
# 0             1      6  4.166667
# 1         10000      5  1.000000
# 2        100006      1  0.000000
# 3      10000613      2  0.000000
# 4      10001693      1  0.000000
# ...         ...    ...       ...
# 33440      9997      1  0.000000
# 33441      9998      7  0.714286
# 33442    999816      1  0.000000
# 33443    999898      1  0.000000
# 33444      9999      5  0.000000
#
#                                                  title_x  ratings_x  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...    1713866
# 1                                    The Face of Another       2079
# 2      Schrodinger's Kittens and the Search for Reali...       1095
# 3      Getting Better: Why Global Development Is Succ...        122
# 4                       The Hard Way (Jack Reacher, #10)        286
# ...                                                  ...        ...
# 33440                                     The Ruined Map       1158
# 33441                             The Woman in the Dunes      11841
# 33442                                     Home to Harlem        882
# 33443                                     Twelve Pillars        901
# 33444                                        The Box Man       2791
#
#                                                    url_x  \
# 0      https://www.goodreads.com/book/show/1.Harry_Po...
# 1      https://www.goodreads.com/book/show/10000.The_...
# 2      https://www.goodreads.com/book/show/100006.Sch...
# 3      https://www.goodreads.com/book/show/10000613-g...
# 4      https://www.goodreads.com/book/show/10001693-t...
# ...                                                  ...
# 33440  https://www.goodreads.com/book/show/9997.The_R...
# 33441  https://www.goodreads.com/book/show/9998.The_W...
# 33442  https://www.goodreads.com/book/show/999816.Hom...
# 33443  https://www.goodreads.com/book/show/999898.Twe...
# 33444  https://www.goodreads.com/book/show/9999.The_B...
#
#                                            cover_image_x  \
# 0      https://images.gr-assets.com/books/1361039191m...
# 1      https://images.gr-assets.com/books/1320415026m...
# 2      https://images.gr-assets.com/books/1344269008m...
# 3      https://images.gr-assets.com/books/1328841746m...
# 4      https://images.gr-assets.com/books/1328909432m...
# ...                                                  ...
# 33440  https://images.gr-assets.com/books/1320459931m...
# 33441  https://images.gr-assets.com/books/1361254930m...
# 33442  https://s.gr-assets.com/assets/nophoto/book/11...
# 33443  https://images.gr-assets.com/books/1360435414m...
# 33444  https://images.gr-assets.com/books/1320459929m...
#
#                                              mod_title_x  \
# 0      harry potter and the halfblood prince harry po...
# 1                                    the face of another
# 2      schrodingers kittens and the search for realit...
# 3      getting better why global development is succe...
# 4                           the hard way jack reacher 10
# ...                                                  ...
# 33440                                     the ruined map
# 33441                             the woman in the dunes
# 33442                                     home to harlem
# 33443                                     twelve pillars
# 33444                                        the box man
#
#                                                  title_y  ratings_y  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...    1713866
# 1                                    The Face of Another       2079
# 2      Schrodinger's Kittens and the Search for Reali...       1095
# 3      Getting Better: Why Global Development Is Succ...        122
# 4                       The Hard Way (Jack Reacher, #10)        286
# ...                                                  ...        ...
# 33440                                     The Ruined Map       1158
# 33441                             The Woman in the Dunes      11841
# 33442                                     Home to Harlem        882
# 33443                                     Twelve Pillars        901
# 33444                                        The Box Man       2791
#
#                                                    url_y  \
# 0      https://www.goodreads.com/book/show/1.Harry_Po...
# 1      https://www.goodreads.com/book/show/10000.The_...
# 2      https://www.goodreads.com/book/show/100006.Sch...
# 3      https://www.goodreads.com/book/show/10000613-g...
# 4      https://www.goodreads.com/book/show/10001693-t...
# ...                                                  ...
# 33440  https://www.goodreads.com/book/show/9997.The_R...
# 33441  https://www.goodreads.com/book/show/9998.The_W...
# 33442  https://www.goodreads.com/book/show/999816.Hom...
# 33443  https://www.goodreads.com/book/show/999898.Twe...
# 33444  https://www.goodreads.com/book/show/9999.The_B...
#
#                                            cover_image_y  \
# 0      https://images.gr-assets.com/books/1361039191m...
# 1      https://images.gr-assets.com/books/1320415026m...
# 2      https://images.gr-assets.com/books/1344269008m...
# 3      https://images.gr-assets.com/books/1328841746m...
# 4      https://images.gr-assets.com/books/1328909432m...
# ...                                                  ...
# 33440  https://images.gr-assets.com/books/1320459931m...
# 33441  https://images.gr-assets.com/books/1361254930m...
# 33442  https://s.gr-assets.com/assets/nophoto/book/11...
# 33443  https://images.gr-assets.com/books/1360435414m...
# 33444  https://images.gr-assets.com/books/1320459929m...
#
#                                              mod_title_y
# 0      harry potter and the halfblood prince harry po...
# 1                                    the face of another
# 2      schrodingers kittens and the search for realit...
# 3      getting better why global development is succe...
# 4                           the hard way jack reacher 10
# ...                                                  ...
# 33440                                     the ruined map
# 33441                             the woman in the dunes
# 33442                                     home to harlem
# 33443                                     twelve pillars
# 33444                                        the box man
#
# [33445 rows x 13 columns]

# %%
#normalized count of times the book appeared for similar users relative to others
book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["ratings"])
book_recs["score"] = book_recs["mean"] * book_recs["adjusted_count"]

#remove books we've already read based on id
book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]

#create mod_title (like in other notebook)
my_books["mod_title"] = (
    my_books["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True)
    .str.lower()
    .str.replace("\s+", " ", regex=True)
)

#remove books we've already read based on mod_title
book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]

#remove books that appeared fewer than 2 times, whose mean rating > 4
book_recs = book_recs[book_recs["count"]>2]
book_recs = book_recs[book_recs["mean"] >=4]

#sort based on score
top_recs = book_recs.sort_values("score", ascending=False)

# %%
def make_clickable(val):
    return f'<a target="_blank" href="{val}">Goodreads</a>'

def show_image(val):
    return f'<img src="{val}" width=50></img>'

top_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_2d099">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d099_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_2d099_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_2d099_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_2d099_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_2d099_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_2d099_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_2d099_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_2d099_level0_col7" class="col_heading level0 col7" >mod_title</th>
#       <th id="T_2d099_level0_col8" class="col_heading level0 col8" >adjusted_count</th>
#       <th id="T_2d099_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d099_level0_row0" class="row_heading level0 row0" >6196</th>
#       <td id="T_2d099_row0_col0" class="data row0 col0" >15241</td>
#       <td id="T_2d099_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_2d099_row0_col2" class="data row0 col2" >4.800000</td>
#       <td id="T_2d099_row0_col3" class="data row0 col3" >The Two Towers (The Lord of the Rings, #2)</td>
#       <td id="T_2d099_row0_col4" class="data row0 col4" >490005</td>
#       <td id="T_2d099_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/15241.The_Two_Towers">Goodreads</a></td>
#       <td id="T_2d099_row0_col6" class="data row0 col6" ><img src="https://images.gr-assets.com/books/1298415523m/15241.jpg" width=50></img></td>
#       <td id="T_2d099_row0_col7" class="data row0 col7" >the two towers the lord of the rings 2</td>
#       <td id="T_2d099_row0_col8" class="data row0 col8" >0.000051</td>
#       <td id="T_2d099_row0_col9" class="data row0 col9" >0.000245</td>
#     </tr>
#     <tr>
#       <th id="T_2d099_level0_row1" class="row_heading level0 row1" >9689</th>
#       <td id="T_2d099_row1_col0" class="data row1 col0" >18512</td>
#       <td id="T_2d099_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_2d099_row1_col2" class="data row1 col2" >4.800000</td>
#       <td id="T_2d099_row1_col3" class="data row1 col3" >The Return of the King (The Lord of the Rings, #3)</td>
#       <td id="T_2d099_row1_col4" class="data row1 col4" >473101</td>
#       <td id="T_2d099_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/18512.The_Return_of_the_King">Goodreads</a></td>
#       <td id="T_2d099_row1_col6" class="data row1 col6" ><img src="https://images.gr-assets.com/books/1389977161m/18512.jpg" width=50></img></td>
#       <td id="T_2d099_row1_col7" class="data row1 col7" >the return of the king the lord of the rings 3</td>
#       <td id="T_2d099_row1_col8" class="data row1 col8" >0.000053</td>
#       <td id="T_2d099_row1_col9" class="data row1 col9" >0.000254</td>
#     </tr>
#     <tr>
#       <th id="T_2d099_level0_row2" class="row_heading level0 row2" >25361</th>
#       <td id="T_2d099_row2_col0" class="data row2 col0" >59960</td>
#       <td id="T_2d099_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_2d099_row2_col2" class="data row2 col2" >4.666667</td>
#       <td id="T_2d099_row2_col3" class="data row2 col3" >Batman: The Dark Knight Returns (The Dark Knight Saga, #1)</td>
#       <td id="T_2d099_row2_col4" class="data row2 col4" >136853</td>
#       <td id="T_2d099_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/59960.Batman">Goodreads</a></td>
#       <td id="T_2d099_row2_col6" class="data row2 col6" ><img src="https://images.gr-assets.com/books/1327892039m/59960.jpg" width=50></img></td>
#       <td id="T_2d099_row2_col7" class="data row2 col7" >batman the dark knight returns the dark knight saga 1</td>
#       <td id="T_2d099_row2_col8" class="data row2 col8" >0.000066</td>
#       <td id="T_2d099_row2_col9" class="data row2 col9" >0.000307</td>
#     </tr>
#     <tr>
#       <th id="T_2d099_level0_row3" class="row_heading level0 row3" >3845</th>
#       <td id="T_2d099_row3_col0" class="data row3 col0" >12985</td>
#       <td id="T_2d099_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_2d099_row3_col2" class="data row3 col2" >4.666667</td>
#       <td id="T_2d099_row3_col3" class="data row3 col3" >The Tempest</td>
#       <td id="T_2d099_row3_col4" class="data row3 col4" >127830</td>
#       <td id="T_2d099_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/12985.The_Tempest">Goodreads</a></td>
#       <td id="T_2d099_row3_col6" class="data row3 col6" ><img src="https://images.gr-assets.com/books/1327793692m/12985.jpg" width=50></img></td>
#       <td id="T_2d099_row3_col7" class="data row3 col7" >the tempest</td>
#       <td id="T_2d099_row3_col8" class="data row3 col8" >0.000070</td>
#       <td id="T_2d099_row3_col9" class="data row3 col9" >0.000329</td>
#     </tr>
#     <tr>
#       <th id="T_2d099_level0_row4" class="row_heading level0 row4" >27120</th>
#       <td id="T_2d099_row4_col0" class="data row4 col0" >6689</td>
#       <td id="T_2d099_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_2d099_row4_col2" class="data row4 col2" >4.333333</td>
#       <td id="T_2d099_row4_col3" class="data row4 col3" >James and the Giant Peach</td>
#       <td id="T_2d099_row4_col4" class="data row4 col4" >276439</td>
#       <td id="T_2d099_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/6689.James_and_the_Giant_Peach">Goodreads</a></td>
#       <td id="T_2d099_row4_col6" class="data row4 col6" ><img src="https://images.gr-assets.com/books/1320412586m/6689.jpg" width=50></img></td>
#       <td id="T_2d099_row4_col7" class="data row4 col7" >james and the giant peach</td>
#       <td id="T_2d099_row4_col8" class="data row4 col8" >0.000033</td>
#       <td id="T_2d099_row4_col9" class="data row4 col9" >0.000141</td>
#     </tr>
#     <tr>
#       <th id="T_2d099_level0_row5" class="row_heading level0 row5" >8817</th>
#       <td id="T_2d099_row5_col0" class="data row5 col0" >17881</td>
#       <td id="T_2d099_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_2d099_row5_col2" class="data row5 col2" >4.333333</td>
#       <td id="T_2d099_row5_col3" class="data row5 col3" >Notes from Underground & The Double</td>
#       <td id="T_2d099_row5_col4" class="data row5 col4" >4200</td>
#       <td id="T_2d099_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/17881.Notes_from_Underground_The_Double">Goodreads</a></td>
#       <td id="T_2d099_row5_col6" class="data row5 col6" ><img src="https://images.gr-assets.com/books/1399385623m/17881.jpg" width=50></img></td>
#       <td id="T_2d099_row5_col7" class="data row5 col7" >notes from underground the double</td>
#       <td id="T_2d099_row5_col8" class="data row5 col8" >0.002143</td>
#       <td id="T_2d099_row5_col9" class="data row5 col9" >0.009286</td>
#     </tr>
#     <tr>
#       <th id="T_2d099_level0_row6" class="row_heading level0 row6" >10134</th>
#       <td id="T_2d099_row6_col0" class="data row6 col0" >1885</td>
#       <td id="T_2d099_row6_col1" class="data row6 col1" >6</td>
#       <td id="T_2d099_row6_col2" class="data row6 col2" >4.333333</td>
#       <td id="T_2d099_row6_col3" class="data row6 col3" >Pride and Prejudice</td>
#       <td id="T_2d099_row6_col4" class="data row6 col4" >2078406</td>
#       <td id="T_2d099_row6_col5" class="data row6 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/1885.Pride_and_Prejudice">Goodreads</a></td>
#       <td id="T_2d099_row6_col6" class="data row6 col6" ><img src="https://images.gr-assets.com/books/1320399351m/1885.jpg" width=50></img></td>
#       <td id="T_2d099_row6_col7" class="data row6 col7" >pride and prejudice</td>
#       <td id="T_2d099_row6_col8" class="data row6 col8" >0.000017</td>
#       <td id="T_2d099_row6_col9" cla
