# %% [markdown]
# # Import Libraries & Tools

# %%
import pandas as pd
import numpy as np

from scipy.sparse import coo_matrix
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Import Data

# %%
my_books = pd.read_csv('liked_books.csv')

#ensure `book_id` is a string
my_books['book_id'] = my_books['book_id'].astype(str)
my_books.head()
# Out:
#    user_id   book_id  rating                   title
# 0       -1    434903       5     The Rings of Saturn
# 1       -1  11047557       5   The Lord of the Rings
# 2       -1  29983711       5                Pachinko
# 3       -1  12073240       5  The Remains of the Day
# 4       -1     11297       5          Norwegian Wood

# %% [markdown]
# # Find Similar Users

# %%
#get the correct book_id values
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

#ensure no duplicates in our book list
book_set = set(my_books['book_id'])

# %%
#get # of times a user read a book on our list
overlap_users = {}

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        book_id = csv_book_mapping.get(csv_id)
        
        if book_id in book_set:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1

# %%
#filter users who have read 25% or more of the books in my_books
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/4])

print(f'# of users who have read at least 1 book on our list: {len(overlap_users)}')
print(f'# of users who have read at least 25% of books on our list: {len(filtered_overlap_users)}')
# Out:
# # of users who have read at least 1 book on our list: 97461
# # of users who have read at least 25% of books on our list: 92

# %% [markdown]
# # Find Similar Users Ratings

# %%
#get users book list
interactions_list = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, book_id, rating])

# %% [markdown]
# # Create Collaborative Filtering Matrix

# %%
#create df with similar users book lists and add our book list to it
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])
interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions])
interactions
# Out:
#         user_id   book_id rating
# 0            -1    434903      5
# 1            -1  11047557      5
# 2            -1  29983711      5
# 3            -1  12073240      5
# 4            -1     11297      5
# ...         ...       ...    ...
# 1139179  437856  30091914      5
# 1139180  437856  23281518      4
# 1139181  437856  27430351      5
# 1139182  437856  33295190      0
# 1139183  437856  28052185      5
#
# [1139209 rows x 3 columns]

# %%
#ensure columns are correct dtypes
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

#gives sequential index for user and book id
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

#calculates coo_matrix
ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))
ratings_mat_coo.shape
# Out:
# (93, 421622)

# %% [markdown]
# # Finding Users Similar To Us

# %%
ratings_mat = ratings_mat_coo.tocsr()
interactions[interactions["user_id"] == "-1"].head()
# Out:
#   user_id   book_id  rating  user_index  book_index
# 0      -1    434903       5           0      323091
# 1      -1  11047557       5           0       14591
# 2      -1  29983711       5           0      269638
# 3      -1  12073240       5           0       28964
# 4      -1     11297       5           0       18294

# %%
#get our index based on above
my_index = 0

#get similarities to other users (closer to 1 = more similar)
similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()
similarity[0]
# Out:
# 1.0000000000000002

# %%
#finds X indices of most similar users to us in terms of book tastes
find_similar_users = 30
indices = np.argpartition(similarity, -find_similar_users)[-find_similar_users:]
indices
# Out:
# array([28, 35, 82, 52, 67, 87, 19, 70, 21, 43, 73, 42, 75, 41,  2, 78, 85,
#        29, 27, 53, 58, 80, 79, 72, 51, 39, 38, 22, 33,  0], dtype=int64)

# %%
#gets user id based on above indices
similar_users = interactions[interactions["user_index"].isin(indices)].copy()
similar_users = similar_users[similar_users["user_id"] != "-1"]
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 13628      3199    939870       4          53      412000
# 13629      3199     15654       4          53       73077
# 13630      3199      5204       3          53      335171
# 13631      3199     17650       4          53      109826
# 13632      3199     42155       4          53      321172
# ...         ...       ...     ...         ...         ...
# 1139179  437856  30091914       5          79      270741
# 1139180  437856  23281518       4          79      193283
# 1139181  437856  27430351       5          79      247153
# 1139182  437856  33295190       0          79      293965
# 1139183  437856  28052185       5          79      251024
#
# [110695 rows x 5 columns]

# %% [markdown]
# # Getting Book Recommendations

# %%
#how many time each book appeared in above recommendations
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean'])
book_recs
# Out:
#           count      mean
# book_id
# 1            16  3.937500
# 10000         7  0.714286
# 10000191      1  0.000000
# 1000059       1  4.000000
# 100006        1  0.000000
# ...         ...       ...
# 9998705       1  0.000000
# 999894        1  0.000000
# 999898        1  0.000000
# 9999          7  0.000000
# 9999107       1  0.000000
#
# [61153 rows x 2 columns]

# %%
#gets book title so that the above makes more sense
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

#merge two datasets to get the titles into our recommendations
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")
book_recs
# Out:
#         book_id  count      mean  \
# 0             1     16  3.937500
# 1         10000      7  0.714286
# 2      10000191      1  0.000000
# 3       1000059      1  4.000000
# 4        100006      1  0.000000
# ...         ...    ...       ...
# 58516   9998705      1  0.000000
# 58517    999894      1  0.000000
# 58518    999898      1  0.000000
# 58519      9999      7  0.000000
# 58520   9999107      1  0.000000
#
#                                                    title  ratings  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 1                                    The Face of Another     2079
# 2                                          Yellow Crocus    17787
# 3                Green Arrow, Vol. 2: Sounds of Violence     1704
# 4      Schrodinger's Kittens and the Search for Reali...     1095
# ...                                                  ...      ...
# 58516          Flash and Bones (Temperance Brennan, #14)    14249
# 58517                              Bell, Book and Candle      133
# 58518                                     Twelve Pillars      901
# 58519                                        The Box Man     2791
# 58520                               The American Heiress    24522
#
#                                                      url  \
# 0      https://www.goodreads.com/book/show/1.Harry_Po...
# 1      https://www.goodreads.com/book/show/10000.The_...
# 2      https://www.goodreads.com/book/show/10000191-y...
# 3      https://www.goodreads.com/book/show/1000059.Gr...
# 4      https://www.goodreads.com/book/show/100006.Sch...
# ...                                                  ...
# 58516  https://www.goodreads.com/book/show/9998705-fl...
# 58517  https://www.goodreads.com/book/show/999894.Bel...
# 58518  https://www.goodreads.com/book/show/999898.Twe...
# 58519  https://www.goodreads.com/book/show/9999.The_B...
# 58520  https://www.goodreads.com/book/show/9999107-th...
#
#                                              cover_image  \
# 0      https://images.gr-assets.com/books/1361039191m...
# 1      https://images.gr-assets.com/books/1320415026m...
# 2      https://s.gr-assets.com/assets/nophoto/book/11...
# 3      https://s.gr-assets.com/assets/nophoto/book/11...
# 4      https://images.gr-assets.com/books/1344269008m...
# ...                                                  ...
# 58516  https://images.gr-assets.com/books/1306253347m...
# 58517  https://s.gr-assets.com/assets/nophoto/book/11...
# 58518  https://images.gr-assets.com/books/1360435414m...
# 58519  https://images.gr-assets.com/books/1320459929m...
# 58520  https://images.gr-assets.com/books/1307342832m...
#
#                                                mod_title
# 0      harry potter and the halfblood prince harry po...
# 1                                    the face of another
# 2                                          yellow crocus
# 3                   green arrow vol 2 sounds of violence
# 4      schrodingers kittens and the search for realit...
# ...                                                  ...
# 58516              flash and bones temperance brennan 14
# 58517                               bell book and candle
# 58518                                     twelve pillars
# 58519                                        the box man
# 58520                               the american heiress
#
# [58521 rows x 8 columns]

# %% [markdown]
# # Ranking Our Book Recommendations

# %%
#normalized count of times the book appeared for similar users relative to others
book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["ratings"])
book_recs["score"] = book_recs["mean"] * book_recs["adjusted_count"]

#remove books we've already read based on id
book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]

#create mod_title (like in other notebook)
my_books["mod_title"] = (
    my_books["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True)
    .str.lower()
    .str.replace("\s+", " ", regex=True)
)

#remove books we've already read based on mod_title
book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]

#remove books that appeared fewer than 2 times, whose mean rating > 4
book_recs = book_recs[book_recs["count"]>2]
book_recs = book_recs[book_recs["mean"] >=4]

#sort based on score
top_recs = book_recs.sort_values("score", ascending=False)

# %% [markdown]
# # Improving Display of Book Recommendations

# %%
def make_clickable(val):
    return f'<a target="_blank" href="{val}">Goodreads</a>'

def show_image(val):
    return f'<img src="{val}" width=50></img>'

top_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_1431f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1431f_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_1431f_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_1431f_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_1431f_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_1431f_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_1431f_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_1431f_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_1431f_level0_col7" class="col_heading level0 col7" >mod_title</th>
#       <th id="T_1431f_level0_col8" class="col_heading level0 col8" >adjusted_count</th>
#       <th id="T_1431f_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1431f_level0_row0" class="row_heading level0 row0" >47282</th>
#       <td id="T_1431f_row0_col0" class="data row0 col0" >672172</td>
#       <td id="T_1431f_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_1431f_row0_col2" class="data row0 col2" >4.000000</td>
#       <td id="T_1431f_row0_col3" class="data row0 col3" >The Altar of the Dead</td>
#       <td id="T_1431f_row0_col4" class="data row0 col4" >237</td>
#       <td id="T_1431f_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/672172.The_Altar_of_the_Dead">Goodreads</a></td>
#       <td id="T_1431f_row0_col6" class="data row0 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_1431f_row0_col7" class="data row0 col7" >the altar of the dead</td>
#       <td id="T_1431f_row0_col8" class="data row0 col8" >0.037975</td>
#       <td id="T_1431f_row0_col9" class="data row0 col9" >0.151899</td>
#     </tr>
#     <tr>
#       <th id="T_1431f_level0_row1" class="row_heading level0 row1" >39919</th>
#       <td id="T_1431f_row1_col0" class="data row1 col0" >475080</td>
#       <td id="T_1431f_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_1431f_row1_col2" class="data row1 col2" >4.333333</td>
#       <td id="T_1431f_row1_col3" class="data row1 col3" >The Suppliants</td>
#       <td id="T_1431f_row1_col4" class="data row1 col4" >351</td>
#       <td id="T_1431f_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/475080.The_Suppliants">Goodreads</a></td>
#       <td id="T_1431f_row1_col6" class="data row1 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_1431f_row1_col7" class="data row1 col7" >the suppliants</td>
#       <td id="T_1431f_row1_col8" class="data row1 col8" >0.025641</td>
#       <td id="T_1431f_row1_col9" class="data row1 col9" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_1431f_level0_row2" class="row_heading level0 row2" >19023</th>
#       <td id="T_1431f_row2_col0" class="data row2 col0" >19107</td>
#       <td id="T_1431f_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_1431f_row2_col2" class="data row2 col2" >4.333333</td>
#       <td id="T_1431f_row2_col3" class="data row2 col3" >Diary of a Madman, The Government Inspector,  Selected Stories</td>
#       <td id="T_1431f_row2_col4" class="data row2 col4" >646</td>
#       <td id="T_1431f_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/19107.Diary_of_a_Madman_The_Government_Inspector_Selected_Stories">Goodreads</a></td>
#       <td id="T_1431f_row2_col6" class="data row2 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_1431f_row2_col7" class="data row2 col7" >diary of a madman the government inspector selected stories</td>
#       <td id="T_1431f_row2_col8" class="data row2 col8" >0.013932</td>
#       <td id="T_1431f_row2_col9" class="data row2 col9" >0.060372</td>
#     </tr>
#     <tr>
#       <th id="T_1431f_level0_row3" class="row_heading level0 row3" >56900</th>
#       <td id="T_1431f_row3_col0" class="data row3 col0" >9484</td>
#       <td id="T_1431f_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_1431f_row3_col2" class="data row3 col2" >5.000000</td>
#       <td id="T_1431f_row3_col3" class="data row3 col3" >Within a Budding Grove (In Search of Lost Time, #2)</td>
#       <td id="T_1431f_row3_col4" class="data row3 col4" >813</td>
#       <td id="T_1431f_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/9484.Within_a_Budding_Grove">Goodreads</a></td>
#       <td id="T_1431f_row3_col6" class="data row3 col6" ><img src="https://images.gr-assets.com/books/1320420357m/9484.jpg" width=50></img></td>
#       <td id="T_1431f_row3_col7" class="data row3 col7" >within a budding grove in search of lost time 2</td>
#       <td id="T_1431f_row3_col8" class="data row3 col8" >0.011070</td>
#       <td id="T_1431f_row3_col9" class="data row3 col9" >0.055351</td>
#     </tr>
#     <tr>
#       <th id="T_1431f_level0_row4" class="row_heading level0 row4" >42553</th>
#       <td id="T_1431f_row4_col0" class="data row4 col0" >556967</td>
#       <td id="T_1431f_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_1431f_row4_col2" class="data row4 col2" >4.000000</td>
#       <td id="T_1431f_row4_col3" class="data row4 col3" >Chamber Music</td>
#       <td id="T_1431f_row4_col4" class="data row4 col4" >652</td>
#       <td id="T_1431f_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/556967.Chamber_Music">Goodreads</a></td>
#       <td id="T_1431f_row4_col6" class="data row4 col6" ><img src="https://images.gr-assets.com/books/1359729967m/556967.jpg" width=50></img></td>
#       <td id="T_1431f_row4_col7" class="data row4 col7" >chamber music</td>
#       <td id="T_1431f_row4_col8" class="data row4 col8" >0.013804</td>
#       <td id="T_1431f_row4_col9" class="data row4 col9" >0.055215</td>
#     </tr>
#     <tr>
#       <th id="T_1431f_level0_row5" class="row_heading level0 row5" >21947</th>
#       <td id="T_1431f_row5_col0" class="data row5 col0" >21976060</td>
#       <td id="T_1431f_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_1431f_row5_col2" class="data row5 col2" >4.333333</td>
#       <td id="T_1431f_row5_col3" class="data row5 col3" >The Art of Stillness: Adventures in Going Nowhere</td>
#       <td id="T_1431f_row5_col4" class="data row5 col4" >2902</td>
#       <td id="T_1431f_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/21976060-the-art-of-stillness">Goodreads</a></td>
#       <td id="T_1431f_row5_col6" class="data row5 col6" ><img src="https://images.gr-assets.com/books/1418670911m/21976060.jpg" width=50></img></td>
#       <td id="T_1431f_row5_col7" class="data row5 col7" >the art of stillness adventures in going nowhere</td>
#       <td id="T_1431f_row5_col8" class="data row5 col8" >0.003101</td>
#       <td id="T_1431f_row5_col9" class="data row5 col9" >0.013439</td>
#     </tr>
#     <tr>
#       <th id="T_1431f_level0_row6" class="row_heading level0 row6" >47544</th>
#       <td id="T_1431f_row6_col0" class="data row6 col0" >6786692</td>
#       <td id="T_1431f_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_1431f_row6_col2" class="data row6 col2" >4.000000</td>
#       <td id="T_1431f_row6_col3" class="data row6 col3" >Battle Royale</td>
#       <td id="T_1431f_row6_col4" class="data row6 col4" >2705</td>
#       <td id="T_1431f_row6_col5" class="data row6 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/6786692-battle-royale">Goodreads</a></td>
#       <td id="T_1431f_row6_col6" class="data row6 col6" ><img src="https://images.gr-assets.com/books/1350148530m/6786692.jpg" width=50></img></td>
#       <td id="T_1431f_row6_col7" class="data row6 col7" >battle royale<
