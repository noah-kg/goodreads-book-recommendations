# %% [markdown]
# # Import Data

# %%
import pandas as pd

#list of our liked books from the search.ipynb
liked_books = ['434903', '11047557', '29983711', '12073240', '11297', '12058235', '7117831', '11909375']

#dict to hold book_id's 
csv_book_mapping = {}

#stream the .csv to add book_ids in csv_book_mapping dict
with open('book_id_map.csv', 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(',')
        csv_book_mapping[csv_id] = book_id

#set of users who have liked a book in our list and rated it 4 or higher
overlap_users = set()

#stream the .csv to get set of users who liked same books and gave it 4+ rating
with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            continue

        try:
            rating = int(rating)
        except ValueError:
            continue
        
        book_id = csv_book_mapping[csv_id]
        
        if book_id in liked_books and rating >= 4:
            overlap_users.add(user_id)

# %%
#list of books that users with similar interests have rated as 4 or higher
rec_lines = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append([user_id, book_id, rating])

# %% [markdown]
# # Data Exploration

# %%
print(f'Books in dataset: {len(csv_book_mapping)}')
print(f'Users with similar tastes: {len(overlap_users)}')
print(f'Books rated > 4 from those users: {len(rec_lines)}')
# Out:
# Books in dataset: 2360651
# Users with similar tastes: 15862
# Books rated > 4 from those users: 6896327

# %%
#create dataframe of initial recommended books
recs = pd.DataFrame(rec_lines, columns=['user_id', 'book_id', 'rating'])
recs['book_id'] = recs['book_id'].astype(str)
recs
# Out:
#         user_id  book_id rating
# 0            32    14050      5
# 1            32      960      3
# 2            32     1618      3
# 3            32    77203      4
# 4            32     4214      4
# ...         ...      ...    ...
# 6896322  876091    13214      0
# 6896323  876091   278216      4
# 6896324  876091     7815      0
# 6896325  876091  1292187      0
# 6896326  876091   135611      0
#
# [6896327 rows x 3 columns]

# %%
#top 10 recommendations based on count
top_recs = recs['book_id'].value_counts().head(10)
top_recs = top_recs.index.values

#read in book titles to match with book_id
books_titles = pd.read_json('books_titles.json')
books_titles['book_id'] = books_titles['book_id'].astype(str)
books_titles.head()
# Out:
#    book_id                                              title  ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1  6066819                               Best Friends Forever    51184
# 2   287141                      The Aeneid for Boys and Girls       46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4   287149                               The Devil's Notebook      986
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...
#
#                                           mod_title
# 0    the unschooled wizard sun wolf and starhawk 12
# 1                              best friends forever
# 2                     the aeneid for boys and girls
# 3  alls fairy in love and war avalon web of magic 8
# 4                               the devils notebook

# %%
#gets book titles whose id is in our top_recs
books_titles[books_titles['book_id'].isin(top_recs)]
# Out:
#         book_id                                              title  ratings  \
# 138759    11297                                     Norwegian Wood   189394
# 284473  2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 401395     5107                             The Catcher in the Rye  2086945
# 463463     4671                                   The Great Gatsby  2758812
# 615314     5470                                               1984  2023937
# 770177     7613                                        Animal Farm  1928931
# 790927     2657                              To Kill a Mockingbird  3255518
# 851581     4929                                 Kafka on the Shore   172711
# 876816      865                                      The Alchemist  1342863
# 878545        3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
#
#                                                       url  \
# 138759  https://www.goodreads.com/book/show/11297.Norw...
# 284473  https://www.goodreads.com/book/show/2767052-th...
# 401395  https://www.goodreads.com/book/show/5107.The_C...
# 463463  https://www.goodreads.com/book/show/4671.The_G...
# 615314      https://www.goodreads.com/book/show/5470.1984
# 770177  https://www.goodreads.com/book/show/7613.Anima...
# 790927  https://www.goodreads.com/book/show/2657.To_Ki...
# 851581  https://www.goodreads.com/book/show/4929.Kafka...
# 876816  https://www.goodreads.com/book/show/865.The_Al...
# 878545  https://www.goodreads.com/book/show/3.Harry_Po...
#
#                                               cover_image  \
# 138759  https://s.gr-assets.com/assets/nophoto/book/11...
# 284473  https://images.gr-assets.com/books/1447303603m...
# 401395  https://images.gr-assets.com/books/1398034300m...
# 463463  https://images.gr-assets.com/books/1490528560m...
# 615314  https://images.gr-assets.com/books/1348990566m...
# 770177  https://images.gr-assets.com/books/1424037542m...
# 790927  https://images.gr-assets.com/books/1361975680m...
# 851581  https://s.gr-assets.com/assets/nophoto/book/11...
# 876816  https://images.gr-assets.com/books/1483412266m...
# 878545  https://images.gr-assets.com/books/1474154022m...
#
#                                                 mod_title
# 138759                                     norwegian wood
# 284473                the hunger games the hunger games 1
# 401395                             the catcher in the rye
# 463463                                   the great gatsby
# 615314                                               1984
# 770177                                        animal farm
# 790927                              to kill a mockingbird
# 851581                                 kafka on the shore
# 876816                                      the alchemist
# 878545  harry potter and the sorcerers stone harry pot...

# %%
#create dataframe of all recommended books, based on book_count
all_recs = recs['book_id'].value_counts()
all_recs = all_recs.to_frame().reset_index()
all_recs.columns = ['book_id', 'book_count']
all_recs
# Out:
#         book_id  book_count
# 0         11297       14303
# 1          4671        8989
# 2          5470        8774
# 3          5107        8589
# 4          2657        8363
# ...         ...         ...
# 743176  7260482           1
# 743177   715815           1
# 743178  1961548           1
# 743179   434015           1
# 743180  2110524           1
#
# [743181 rows x 2 columns]

# %%
#combines all_recs with books_titles
all_recs = all_recs.merge(books_titles, how='inner', on='book_id')

#creates 'score' where books are penalized if they are popular in the general sense
#this helps find books that aren't insanely popular and recommended to everyone
all_recs['score'] = all_recs['book_count'] * (all_recs['book_count'] / all_recs['ratings'])
all_recs.sort_values('score', ascending=False).head(10)
# Out:
#       book_id  book_count                                            title  \
# 0       11297       14303                                   Norwegian Wood
# 5        4929        8096                               Kafka on the Shore
# 39       9557        4783                               Sputnik Sweetheart
# 12   10357575        6315                                             1Q84
# 10      11275        6469                       The Wind-Up Bird Chronicle
# 67      17799        3755             South of the Border, West of the Sun
# 52      17803        4267                                       After Dark
# 79      17800        3368                  Dance Dance Dance (The Rat, #4)
# 348  29983711        1472                                         Pachinko
# 57      10374        4094  Hard-Boiled Wonderland and the End of the World
#
#      ratings                                                url  \
# 0     189394  https://www.goodreads.com/book/show/11297.Norw...
# 5     172711  https://www.goodreads.com/book/show/4929.Kafka...
# 39     63880  https://www.goodreads.com/book/show/9557.Sputn...
# 12    129101  https://www.goodreads.com/book/show/10357575-1q84
# 10    136559  https://www.goodreads.com/book/show/11275.The_...
# 67     48978  https://www.goodreads.com/book/show/17799.Sout...
# 52     65830  https://www.goodreads.com/book/show/17803.Afte...
# 79     42021  https://www.goodreads.com/book/show/17800.Danc...
# 348     8161  https://www.goodreads.com/book/show/29983711-p...
# 57     65374  https://www.goodreads.com/book/show/10374.Hard...
#
#                                            cover_image  \
# 0    https://s.gr-assets.com/assets/nophoto/book/11...
# 5    https://s.gr-assets.com/assets/nophoto/book/11...
# 39   https://images.gr-assets.com/books/1508082438m...
# 12   https://images.gr-assets.com/books/1483103331m...
# 10   https://images.gr-assets.com/books/1327872639m...
# 67   https://images.gr-assets.com/books/1443685506m...
# 52   https://s.gr-assets.com/assets/nophoto/book/11...
# 79   https://images.gr-assets.com/books/1443689019m...
# 348  https://images.gr-assets.com/books/1462393298m...
# 57   https://images.gr-assets.com/books/1399844477m...
#
#                                           mod_title        score
# 0                                    norwegian wood  1080.159926
# 5                                kafka on the shore   379.508057
# 39                               sputnik sweetheart   358.126002
# 12                                             1q84   308.899428
# 10                        the windup bird chronicle   306.446012
# 67              south of the border west of the sun   287.884867
# 52                                       after dark   276.580419
# 79                      dance dance dance the rat 4   269.946551
# 348                                        pachinko   265.504718
# 57   hardboiled wonderland and the end of the world   256.383822

# %% [markdown]
# # Get Recommendations

# %%
popular_recs = all_recs[all_recs['book_count'] > 200].sort_values('score', ascending=False)

def make_clickable(val):
    return f'<a target="_blank" href="{val}">Goodreads</a>'

def show_image(val):
    return f'<img src="{val}" width=50></img>'

popular_recs[~popular_recs['book_id'].isin(liked_books)].head(10).style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a0561">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0561_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_a0561_level0_col1" class="col_heading level0 col1" >book_count</th>
#       <th id="T_a0561_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_a0561_level0_col3" class="col_heading level0 col3" >ratings</th>
#       <th id="T_a0561_level0_col4" class="col_heading level0 col4" >url</th>
#       <th id="T_a0561_level0_col5" class="col_heading level0 col5" >cover_image</th>
#       <th id="T_a0561_level0_col6" class="col_heading level0 col6" >mod_title</th>
#       <th id="T_a0561_level0_col7" class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0561_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_a0561_row0_col0" class="data row0 col0" >4929</td>
#       <td id="T_a0561_row0_col1" class="data row0 col1" >8096</td>
#       <td id="T_a0561_row0_col2" class="data row0 col2" >Kafka on the Shore</td>
#       <td id="T_a0561_row0_col3" class="data row0 col3" >172711</td>
#       <td id="T_a0561_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/4929.Kafka_on_the_Shore">Goodreads</a></td>
#       <td id="T_a0561_row0_col5" class="data row0 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_a0561_row0_col6" class="data row0 col6" >kafka on the shore</td>
#       <td id="T_a0561_row0_col7" class="data row0 col7" >379.508057</td>
#     </tr>
#     <tr>
#       <th id="T_a0561_level0_row1" class="row_heading level0 row1" >39</th>
#       <td id="T_a0561_row1_col0" class="data row1 col0" >9557</td>
#       <td id="T_a0561_row1_col1" class="data row1 col1" >4783</td>
#       <td id="T_a0561_row1_col2" class="data row1 col2" >Sputnik Sweetheart</td>
#       <td id="T_a0561_row1_col3" class="data row1 col3" >63880</td>
#       <td id="T_a0561_row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/9557.Sputnik_Sweetheart">Goodreads</a></td>
#       <td id="T_a0561_row1_col5" class="data row1 col5" ><img src="https://images.gr-assets.com/books/1508082438m/9557.jpg" width=50></img></td>
#       <td id="T_a0561_row1_col6" class="data row1 col6" >sputnik sweetheart</td>
#       <td id="T_a0561_row1_col7" class="data row1 col7" >358.126002</td>
#     </tr>
#     <tr>
#       <th id="T_a0561_level0_row2" class="row_heading level0 row2" >12</th>
#       <td id="T_a0561_row2_col0" class="data row2 col0" >10357575</td>
#       <td id="T_a0561_row2_col1" class="data row2 col1" >6315</td>
#       <td id="T_a0561_row2_col2" class="data row2 col2" >1Q84</td>
#       <td id="T_a0561_row2_col3" class="data row2 col3" >129101</td>
#       <td id="T_a0561_row2_col4" class="data row2 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/10357575-1q84">Goodreads</a></td>
#       <td id="T_a0561_row2_col5" class="data row2 col5" ><img src="https://images.gr-assets.com/books/1483103331m/10357575.jpg" width=50></img></td>
#       <td id="T_a0561_row2_col6" class="data row2 col6" >1q84</td>
#       <td id="T_a0561_row2_col7" class="data row2 col7" >308.899428</td>
#     </tr>
#     <tr>
#       <th id="T_a0561_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_a0561_row3_col0" class="data row3 col0" >11275</td>
#       <td id="T_a0561_row3_col1" class="data row3 col1" >6469</td>
#       <td id="T_a0561_row3_col2" class="data row3 col2" >The Wind-Up Bird Chronicle</td>
#       <td id="T_a0561_row3_col3" class="data row3 col3" >136559</td>
#       <td id="T_a0561_row3_col4" class="data row3 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/11275.The_Wind_Up_Bird_Chronicle">Goodreads</a></td>
#       <td id="T_a0561_row3_col5" class="data row3 col5" ><img src="https://images.gr-assets.com/books/1327872639m/11275.jpg" width=50></img></td>
#       <td id="T_a0561_row3_col6" class="data row3 col6" >the windup bird chronicle</td>
#       <td id="T_a0561_row3_col7" class="data row3 col7" >306.446012</td>
#     </tr>
#     <tr>
#       <th id="T_a0561_level0_row4" class="row_heading level0 row4" >67</th>
#       <td id="T_a0561_row4_col0" class="data row4 col0" >17799</td>
#       <td id="T_a0561_row4_col1" class="data row4 col1" >3755</td>
#       <td id="T_a0561_row4_col2" class="data row4 col2" >South of the Border, West of the Sun</td>
#       <td id="T_a0561_row4_col3" class="data row4 col3" >48978</td>
#       <td id="T_a0561_row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/17799.South_of_the_Border_West_of_the_Sun">Goodreads</a></td>
#       <td id="T_a0561_row4_col5" class="data row4 col5" ><img src="https://images.gr-assets.com/books/1443685506m/17799.jpg" width=50></img></td>
#       <td id="T_a0561_row4_col6" class="data row4 col6" >south of the border west of the sun</td>
#       <td id="T_a0561_row4_col7" class="data row4 col7" >287.884867</td>
#     </tr>
#     <tr>
#       <th id="T_a0561_level0_row5" class="row_heading level0 row5" >52</th>
#       <td id="T_a0561_row5_col0" class="data row5 col0" >17803</td>
#       <td id="T_a0561_row5_col1" class="data row5 col1" >4267</td>
#       <td id="T_a0561_row5_col2" class="data row5 col2" >After Dark</td>
#       <td id="T_a0561_row5_col3" class="data row5 col3" >65830</td>
#       <td id="T_a0561_row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/17803.After_Dark">Goodreads</a></td>
#       <td id="T_a0561_row5_col5" class="data row5 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_a0561_row5_col6" class="data row5 col6" >after dark</td>
#       <td id="T_a0561_row5_col7" class="data row5 col7" >276.580419</td>
#     </tr>
#     <tr>
#       <th id="T_a0561_level0_row6" class="row_heading level0 row6" >79</th>
#       <td id="T_a0561_row6_col0" class="data row6 col0" >17800</td>
#       <td id="T_a0561_row6_col1" class="data row6 col1" >3368</td>
#       <td id="T_a0561_row6_col2" class="data row6 col2" >Dance Dance Dance (The Rat, #4)</td>
#       <td id="T_a0561_row6_col3" class="data row6 col3" >42021</td>
#       <td id="T_a0561_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/17800.Dance_Dance_Dance">Goodreads</a></td>
#       <td id="T_a0561_row6_col5" class="data row6 col5" ><img src="https://images.gr-assets.com/books/1443689019m/17800.jpg" width=50></img></td>
#       <td id="T_a0561_row6_col6" class="data row6 col6" >dance dance dance the rat 4</td>
#       <td id="T_a0561_row6_col7" class="data row6 col7" >269.946551</td>
#     </tr>
#     <tr>
#       <th id="T_a0561_level0_row7" class="row_heading level0 row7" >57</th>
#       <td id="T_a0561_row7_col0" class="data row7 col0" >10374</td>
#       <td id="T_a0561_row7_col1" class="data row7 col1" >4094</td>
#       <td id="T_a0561_row7_col2" class="data row7 col2" >Hard-Boiled Wonderland and the End of the World</td>
#       <td id="T_a0561_row7_col3" class="data row7 col3" >65374</td>
#       <td id="T_a0561_row7_col4" class="data row7 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/10374.Hard_Boiled_Wonderland_and_the_End_of_the_World">Goodreads</a></td>
#       <td id="T_a0561_row7_col5" class="data row7 col5" ><img src="https://images.gr-assets.com/books/1399844477m/10374.jpg" width=50></img></td>
#       <td id="T_a0561_row7_col6" class="data row7 col6" >hardboiled wonderland and the end of the world</td>
#       <td id="T_a0561_row7_col7" class="data row7 col7" >256.383822</td>
#     </tr>
#     <tr>
#       <th id="T_a0561_level0_row8" class="row_heading level0 row8" >1214</th>
#       <td id="T_a0561_row8_col0" class="data row8 col0" >11296</td>
#       <td id="T_a0561_row8_col1" class="data row8 col1" >568</td>
#       <td id="T_a0561_row8_col2" class="data row8 col2" >Har
